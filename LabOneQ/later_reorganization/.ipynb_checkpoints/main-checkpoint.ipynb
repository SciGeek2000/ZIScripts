# %%
import zi_connect
from IO_help import *
from zi_experiments import *

import pprint


device_file = 'GKP_V0_1_27_2025'
device_text_path = 'device_description/' + device_file + '.txt'
with open(device_text_path, 'rb') as f:
    descriptor_shfqc = f.read()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 12
#      10 with open(device_text_path, 'rb') as f:
#      11     descriptor_shfqc = f.read()
# ---> 12 pprint(descriptor_shfqc)
#
# TypeError: 'module' object is not callable

# %%
zi_connect
